# %%
import numpy as np
import pandas as pd

# %%
dados_covid = pd.read_csv("./COVID19.csv")
# para maiores informações sobre este conjunto de dados acessar:
# https://ourworldindata.org/coronavirus

# %%
dados_covid.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  24/02/2020            5          5
# 1      AFG      Asia  Afghanistan  25/02/2020            5          0
# 2      AFG      Asia  Afghanistan  26/02/2020            5          0
# 3      AFG      Asia  Afghanistan  27/02/2020            5          0
# 4      AFG      Asia  Afghanistan  28/02/2020            5          0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
dados_covid = pd.read_csv("./COVID19.csv")
dados_covid = dados_covid[['iso_code','continent','location','date','total_cases','new_cases']]

# %%
dados_covid
# Out:
#      iso_code continent     location        date  total_cases  new_cases
# 0         AFG      Asia  Afghanistan  24/02/2020            5          5
# 1         AFG      Asia  Afghanistan  25/02/2020            5          0
# 2         AFG      Asia  Afghanistan  26/02/2020            5          0
# 3         AFG      Asia  Afghanistan  27/02/2020            5          0
# 4         AFG      Asia  Afghanistan  28/02/2020            5          0
# ...       ...       ...          ...         ...          ...        ...
# 5813      NGA    Africa      Nigeria  06/10/2022       265741        236
# 5814      NGA    Africa      Nigeria  07/10/2022       265741          0
# 5815      NGA    Africa      Nigeria  08/10/2022       265816         75
# 5816      NGA    Africa      Nigeria  09/10/2022       265816          0
# 5817      NGA    Africa      Nigeria  10/10/2022       265816          0
#
# [5818 rows x 6 columns]

# %%
dados_covid.dtypes
# Out:
# iso_code         str
# continent        str
# location         str
# date             str
# total_cases    int64
# new_cases      int64
# dtype: object

# %%
dados_covid.shape
# Out:
# (5818, 6)

# %%
# Métricas de Tendência Central

# %%
média_dos_dados = np.mean(dados_covid["new_cases"])
média_dos_dados
# Out:
# np.float64(8814.365761430045)

# %%
média_dos_dados = dados_covid["new_cases"].mean()
média_dos_dados
# Out:
# np.float64(8814.365761430045)

# %%
mediana_dados = np.median(dados_covid["new_cases"])

# %%
mediana_dados
# Out:
# np.float64(261.0)

# %%
mediana_dos_dados = dados_covid["new_cases"].median()
mediana_dos_dados
# Out:
# np.float64(261.0)

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.17.1

# %%
from scipy import stats

# %%
moda_dados = stats.mode(dados_covid["new_cases"])

# %%
moda_dados
# Out:
# ModeResult(mode=np.int64(0), count=np.int64(805))

# %%
moda_dados[0]
# Out:
# np.int64(0)

# %%
# Métricas de Dispersão dos Dados

# %%
variancia_dados = np.var(dados_covid["new_cases"])
variancia_dados
# Out:
# np.float64(451321915.9280954)

# %%
dados_covid["new_cases"].var()
# Out:
# np.float64(451399502.6421969)

# %%
sd_dados = np.std(dados_covid["new_cases"])
sd_dados
# Out:
# np.float64(21244.338444114834)

# %%
dados_covid["new_cases"].std()
# Out:
# np.float64(21246.164421895)

# %%
max_dados = np.max(dados_covid["new_cases"])
min_dados = np.min(dados_covid["new_cases"])

# %%
print(max_dados, min_dados)
# Out:
# 287149 0

# %%
max_dados = dados_covid["new_cases"].max()
min_dados = dados_covid["new_cases"].min()

# %%
max_dados
# Out:
# np.int64(287149)

# %%
min_dados
# Out:
# np.int64(0)

# %%
faixa_dados = max_dados - min_dados
faixa_dados
# Out:
# np.int64(287149)

# %%
percentil_dados = np.percentile(dados_covid["new_cases"],60)
percentil_dados
# Out:
# np.float64(591.3999999999996)

# %%
quartil_dados = np.quantile(dados_covid["new_cases"],0.75)
quartil_dados
# Out:
# np.float64(3666.0)

# %%
IQR_dados = stats.iqr(dados_covid["new_cases"], interpolation = 'midpoint')
IQR_dados
# Out:
# np.float64(3641.0)

# %%
IQR_dados = stats.iqr(dados_covid["new_cases"])
IQR_dados
# Out:
# np.float64(3642.0)

# %%
# deverão pesquisar o motivo do IQR dar diferente entre as duas versões anteriores
# sugiro verificar o help de cada função
