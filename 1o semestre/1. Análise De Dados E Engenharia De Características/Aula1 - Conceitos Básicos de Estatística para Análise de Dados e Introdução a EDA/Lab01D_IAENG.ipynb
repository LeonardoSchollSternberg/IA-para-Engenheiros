# %%
# baixar inicialmente do MCOnf da disciplina a base de dados
# chamada de 'adultos.csv"
# salvar a mesma em diretório a sua escolha
# observar o endereço do diretório ao "ler" esta base de dados

# %%
import pandas as pd
import numpy as np

# %%
base_adulto = pd.read_csv('./adulto.csv')

# %%
base_adulto.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capitalGain  capitalLoss  hoursPerWeek  nativeCountry income
# 0         2174            0            40  United-States  <=50K
# ...

# %%
type(base_adulto.age)
# Out:
# pandas.Series

# %%
type(base_adulto)
# Out:
# pandas.DataFrame

# %%
base_adulto.loc[0].index
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capitalGain', 'capitalLoss', 'hoursPerWeek', 'nativeCountry',
#        'income'],
#       dtype='str')

# %%
base_adulto.age.index
# Out:
# RangeIndex(start=0, stop=32561, step=1)

# %%
base_adulto.workclass.index
# Out:
# RangeIndex(start=0, stop=32561, step=1)

# %%
len(base_adulto)
# Out:
# 32561

# %%
base_adulto.set_index(np.arange(10000,42561),inplace=True)

# %%
base_adulto.set_index(np.arange(10000,42561))
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 10000   39         State-gov   77516   Bachelors             13
# 10001   50  Self-emp-not-inc   83311   Bachelors             13
# 10002   38           Private  215646     HS-grad              9
# 10003   53           Private  234721        11th              7
# 10004   28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 42556   27           Private  257302  Assoc-acdm             12
# 42557   40           Private  154374     HS-grad              9
# 42558   58           Private  151910     HS-grad              9
# 42559   22           Private  201490     HS-grad              9
# 42560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 10000       Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
base_adulto.loc[10001]
# Out:
# age                               50
# workclass           Self-emp-not-inc
# fnlwgt                         83311
# education                  Bachelors
# education-num                     13
# marital-status    Married-civ-spouse
# occupation           Exec-managerial
# relationship                 Husband
# race                           White
# sex                             Male
# capitalGain                        0
# capitalLoss                        0
# hoursPerWeek                      13
# nativeCountry          United-States
# income                         <=50K
# Name: 10001, dtype: object

# %%
base_adulto.iloc[1]
# Out:
# age                               50
# workclass           Self-emp-not-inc
# fnlwgt                         83311
# education                  Bachelors
# education-num                     13
# marital-status    Married-civ-spouse
# occupation           Exec-managerial
# relationship                 Husband
# race                           White
# sex                             Male
# capitalGain                        0
# capitalLoss                        0
# hoursPerWeek                      13
# nativeCountry          United-States
# income                         <=50K
# Name: 10001, dtype: object

# %%
base_adulto.age
# Out:
# 10000    39
# 10001    50
# 10002    38
# 10003    53
# 10004    28
#          ..
# 42556    27
# 42557    40
# 42558    58
# 42559    22
# 42560    52
# Name: age, Length: 32561, dtype: int64

# %%
base_adulto.occupation
# Out:
# 10000         Adm-clerical
# 10001      Exec-managerial
# 10002    Handlers-cleaners
# 10003    Handlers-cleaners
# 10004       Prof-specialty
#                ...
# 42556         Tech-support
# 42557    Machine-op-inspct
# 42558         Adm-clerical
# 42559         Adm-clerical
# 42560      Exec-managerial
# Name: occupation, Length: 32561, dtype: str

# %%
base_adulto['age']
# Out:
# 10000    39
# 10001    50
# 10002    38
# 10003    53
# 10004    28
#          ..
# 42556    27
# 42557    40
# 42558    58
# 42559    22
# 42560    52
# Name: age, Length: 32561, dtype: int64

# %%
base_adulto.iloc[2].loc['education']
# Out:
# 'HS-grad'

# %%
base_adulto.education.loc[10002]
# Out:
# 'HS-grad'

# %%
base_adulto['education'].iloc[2]
# Out:
# 'HS-grad'

# %%
base_adulto.at[10002,'education']
# Out:
# 'HS-grad'
