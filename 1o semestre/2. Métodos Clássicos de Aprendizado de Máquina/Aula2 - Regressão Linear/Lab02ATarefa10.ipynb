# %%
# LAB 04A 
# TAREFA 12

# %%
import pandas as pd
dados = pd.read_csv('./baseadaptada01.txt', sep='\t')
dados.head()
# Out:
#     BP  Age  Weight   BSA  Dur  Pulse  Stress
# 0  105   47    85.4  1.75  5.1     63      33
# 1  115   49    94.2  2.10  3.8     70      14
# 2  116   49    95.3  1.98  8.2     72      10
# 3  117   50    94.7  2.01  5.8     73      99
# 4  112   51    89.4  1.89  7.0     72      95

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr=dados.corr()
sns.heatmap(corr, annot=True, cmap='YlGnBu')
plt.show()

# %%
import pandas as pd
dados=pd.DataFrame({'Gênero':['F','M','M','F','M']})
dados.head()
# Out:
#   Gênero
# 0      F
# 1      M
# 2      M
# 3      F
# 4      M

# %%
dados_codificados = pd.get_dummies(dados['Gênero'])
dados_codificados.head()
# Out:
#        F      M
# 0   True  False
# 1  False   True
# 2  False   True
# 3   True  False
# 4  False   True

# %%
dados_codificados = pd.get_dummies(dados['Gênero'], drop_first=True)
dados_codificados.head()
# Out:
#        M
# 0  False
# 1   True
# 2   True
# 3  False
# 4   True
