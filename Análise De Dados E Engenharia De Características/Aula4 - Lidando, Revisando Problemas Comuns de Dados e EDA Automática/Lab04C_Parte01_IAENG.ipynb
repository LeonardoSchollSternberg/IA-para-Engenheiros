# %% [markdown]
# #Lab04C_Parte01_IAENG

# %% [markdown]
# # instalar:

# %% [markdown]
# # pip install ydata_profiling

# %% [markdown]
# # !pip3 install dtale

# %% [markdown]
# # !pip3 install autoviz

# %% [markdown]
# # !pip3 install sweetviz

# %% [markdown]
# #

# %% [markdown]
# # EDA Automático com o Pandas profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
dados_covid = pd.read_csv("C:/Users/abalb/Desktop/covid.csv")
dados_covid

# %%
# Antes criar uma pasta - neste exemplo criei no Desktop a pasta chamada Registros
profile = ProfileReport(dados_covid)
profile.to_file("C:/Users/abalb/Desktop/Registros/profile_output.html")

# %% [markdown]
# # Agora procurar a pasta e abrir o arquivo de saída

# %%
# sugestão - consultar:
# https://docs.profiling.ydata.ai/latest/advanced_settings/available_settings/

# %% [markdown]
# #

# %% [markdown]
# # EDA Automático com o dtale

# %%
import pandas as pd
import dtale

# %%
dados_covid = pd.read_csv("C:/Users/abalb/Desktop/covid.csv")

# %%
dtale.show(dados_covid).open_browser()

# %%
# abrir um browser
# na minha máquina uso Microsoft Edge e funciona muito bem - deveria funcionar na maioria dos browser

# %% [markdown]
# # pesquisar nas várias abas (menus)

# %%
# sugestão - consultar:
# https://dtale.readthedocs.io/en/latest/

# %% [markdown]
# #

# %% [markdown]
# # Realizando EDA automatizada com o AutoViz

# %%
import pandas as pd
from autoviz.AutoViz_Class import AutoViz_Class

# %%
dados_covid = pd.read_csv("C:/Users/abalb/Desktop/covid.csv")

# %%
# %matplotlib inline

# %%
viz = AutoViz_Class()
df = viz.AutoViz(filename = '',dfte= dados_covid, verbose =1)

# %%
# sugestão - consultar:
# https://github.com/AutoViML/AutoViz

# %% [markdown]
# #

# %% [markdown]
# # Deixo também como sugestão a pesquisa na ferramenta Sweetviz
